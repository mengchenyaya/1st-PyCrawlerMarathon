# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 6
#
# [新聞] 口罩被斷貨 量販店飆罵：要員工去超商排
#
#
# KTR5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 KTR5566 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# [問卦] 我突然釋懷的笑 笑聲盤旋半山腰？
#
#
# jerry46593
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jerry46593 的文章
#
#
#  1/31
#
#
#
#
# 4
#
# [問卦] 台灣人是不是防疫觀念不錯？
#
#
# mzwj
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 mzwj 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# Re: [問卦] 高雄武漢肺炎大型收容所要叫什麼名字好
#
#
# richshen
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 richshen 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] moptt點到「公告」都會死機==
#
#
# Wardyal
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Wardyal 的文章
#
#
#  1/31
#
#
#
#
# 3
#
# [問卦] 格陵蘭沒事，人類是不是有救了？
#
#
# Alook
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Alook 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 其實武漢肺炎沒那麼可怕吧
#
#
# h965715
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 h965715 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 每個年齡層看A片是用什麼心態?
#
#
# bonfferoni
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 bonfferoni 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# [新聞] 武漢肺炎》台灣燈會30週年特展「VR體驗
#
#
# ymuit
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ymuit 的文章
#
#
#  1/31
#
#
#
#
#
#
# Re: [問卦] 陳秋實沒更新了，為啥？
#
#
# qqqwsd
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 qqqwsd 的文章
#
#
#  1/31
#
#
#
#
#
#
# Re: [問卦] 台積電如果買不到口罩
#
#
# sinpin
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 sinpin 的文章
#
#
#  1/31
#
#
#
#
#
#
# [新聞] 因應武漢肺炎大學是否延後開學 校長建議
#
#
# huchihkuei01
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 huchihkuei01 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 喜歡熱液從洞裡流出來的感覺
#
#
# Yude0109
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Yude0109 的文章
#
#
#  1/31
#
#
#
#
#
# 62
#
# [公告] 請勿散佈錯假訊息
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/22
# M
#
#
#
# 6
#
# Fw: [徵求] 行車紀錄器 1/19 民生社區 下午五點半左
#
#
# maxjoiny
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maxjoiny 的文章
#
#
#  1/26
#
#
#
#
# 22
#
# [公告] 因應武漢肺炎即時官方訊息暨討論區
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/25
# M
#
#
#
# 5
#
# [公告] 八卦板主徵選報名2/1開始
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 3
#
# [公告] 關於板上疫情相關問卦&八卦板板規
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
